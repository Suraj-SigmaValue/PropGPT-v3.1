# %%
from graph_agent import create_graph, get_graph_image
from IPython.display import Image, display

# Create the graph app
app = create_graph()

# Get the graph image
img = get_graph_image(app)

#displaying

display(Image(img))
